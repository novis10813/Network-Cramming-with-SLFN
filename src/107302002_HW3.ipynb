# %%
import torch
import torch.nn as nn
import torch.optim as optim
import copy
import random

from TrainingAlgorithm import TrainingAlgo, train
from DataPreprocess import create_dataloader
from model import TwoLayerNN

# %%
def All_r_LG_UA_w_LG_UA(model=None,
                        reg_params=None,
                        weight_params=None,
                        l2_lambda=0.001,
                        l1_lambda=0.001,
                        k=1,
                        p=50):
    
    prune_index = 0
    
    while not k>p:
        prune_index = random.randint(0, 127)
        
        model = train_algo.multiclass_regularization(epochs=reg_params['epochs'],
                                                    model=model,
                                                    optimizer=reg_params['optimizer'],
                                                    loss_threshold=reg_params['loss_threshold'],
                                                    eta_threshold=reg_params['eta_threshold'],
                                                    l2_lambda=l2_lambda,
                                                    l1_lambda=l1_lambda)
        
        saved_model = copy.deepcopy(model)
        
        model.del_neuron(index=prune_index)
        
        situation, model = train_algo.multiclass_weight_tuning(epochs=weight_params['epochs'],
                                                        model=model,
                                                        optimizer=weight_params['optimizer'],
                                                        loss_threshold=weight_params['loss_threshold'],
                                                        eta_threshold=weight_params['eta_threshold'])
        
        if situation == 'Unacceptable':
            model = saved_model
            k += 1
        
        elif situation == 'Acceptable':
            p -= 1
    
    return model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = TwoLayerNN(12, 128, 1, batch_norm=True, dropout=True).to(device)
train_loader, val_loader = create_dataloader()

# initial training
epochs = 20
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-3)

model = train(train_loader, val_loader, model=model, epochs=epochs, optimizer=optimizer, criterion=criterion, device=device)
# Out:
# [ 1/20 ] | train_loss = 0.80638, train_acc = 0.42708, val_loss = 0.77759, val_acc = 0.39583
# [ 2/20 ] | train_loss = 0.78011, train_acc = 0.44271, val_loss = 0.74927, val_acc = 0.41667
# [ 3/20 ] | train_loss = 0.73371, train_acc = 0.47917, val_loss = 0.72049, val_acc = 0.43750
# [ 4/20 ] | train_loss = 0.74466, train_acc = 0.48438, val_loss = 0.68351, val_acc = 0.51042
# [ 5/20 ] | train_loss = 0.68992, train_acc = 0.53385, val_loss = 0.63668, val_acc = 0.48958
# [ 6/20 ] | train_loss = 0.69573, train_acc = 0.53385, val_loss = 0.64471, val_acc = 0.52083
# [ 7/20 ] | train_loss = 0.66619, train_acc = 0.57812, val_loss = 0.68900, val_acc = 0.52083
# [ 8/20 ] | train_loss = 0.64704, train_acc = 0.60156, val_loss = 0.65994, val_acc = 0.51042
# [ 9/20 ] | train_loss = 0.62945, train_acc = 0.64583, val_loss = 0.69853, val_acc = 0.54167
# [ 10/20 ] | train_loss = 0.61951, train_acc = 0.65104, val_loss = 0.66752, val_acc = 0.57292
# [ 11/20 ] | train_loss = 0.63160, train_acc = 0.60417, val_loss = 0.57356, val_acc = 0.57292
# [ 12/20 ] | train_loss = 0.62005, train_acc = 0.65365, val_loss = 0.57763, val_acc = 0.57292
# [ 13/20 ] | train_loss = 0.61102, train_acc = 0.66927, val_loss = 0.62519, val_acc = 0.60417
# [ 14/20 ] | train_loss = 0.59524, train_acc = 0.67708, val_loss = 0.54347, val_acc = 0.65625
# [ 15/20 ] | train_loss = 0.59954, train_acc = 0.65885, val_loss = 0.58829, val_acc = 0.58333
# [ 16/20 ] | train_loss = 0.60331, train_acc = 0.68750, val_loss = 0.68017, val_acc = 0.63542
# [ 17/20 ] | train_loss = 0.56809, train_acc = 0.70833, val_loss = 0.58688, val_acc = 0.67708
# [ 18/20 ] | train_loss = 0.57786, train_acc = 0.72396, val_loss = 0.47888, val_acc = 0.64583
# [ 19/20 ] | train_loss = 0.56255, train_acc = 0.71615, val_loss = 0.46912, val_acc = 0.68750
# [ 20/20 ] | train_loss = 0.58287, train_acc = 0.71875, val_loss = 0.48503, val_acc = 0.69792

# %%
# parameters for different task
reg_optimizer = optim.RMSprop(model.parameters(), lr=1e-3)
reg_loss_threshold = 0.7
reg_eta_threshold = 1e-7
reg_epochs = None

weight_optimizer = optim.RMSprop(model.parameters(), lr=2e-3)
weight_loss_threshold = 0.8
weight_eta_threshold = 1e-10
weight_epochs = 10

reg = {'optimizer': reg_optimizer,
       'loss_threshold': reg_loss_threshold,
       'eta_threshold': reg_eta_threshold,
       'epochs': reg_epochs}

weight = {'optimizer': weight_optimizer,
          'loss_threshold': weight_loss_threshold,
          'eta_threshold': weight_eta_threshold,
          'epochs': weight_epochs}

train_algo = TrainingAlgo(train_loader, val_loader, criterion, device)
model = All_r_LG_UA_w_LG_UA(model, reg, weight, l2_lambda=0.001, p=50)
# Out:
# --------initializing regularization--------
# max loss:0.8717529773712158 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.49213, train_acc = 0.77604, val_loss = 0.51689, val_acc = 0.81250
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.57818, train_acc = 0.72917, val_loss = 0.44364, val_acc = 0.71875
# [ 2/10 ] | train_loss = 0.57758, train_acc = 0.72917, val_loss = 0.77102, val_acc = 0.71875
# [ 3/10 ] | train_loss = 0.57097, train_acc = 0.73438, val_loss = 0.49953, val_acc = 0.70833
# --------initializing regularization--------
# max loss:0.7812615633010864 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.58325, train_acc = 0.69271, val_loss = 0.75738, val_acc = 0.71875
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.59740, train_acc = 0.69792, val_loss = 0.44062, val_acc = 0.71875
# [ 2/10 ] | train_loss = 0.57585, train_acc = 0.72656, val_loss = 0.79063, val_acc = 0.69792
# [ 3/10 ] | train_loss = 0.57375, train_acc = 0.74479, val_loss = 0.57184, val_acc = 0.68750
# [ 4/10 ] | train_loss = 0.57119, train_acc = 0.73438, val_loss = 0.44777, val_acc = 0.69792
# --------initializing regularization--------
# max loss:0.8077396154403687 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.58189, train_acc = 0.71875, val_loss = 0.76798, val_acc = 0.65625
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.59909, train_acc = 0.73177, val_loss = 0.49917, val_acc = 0.67708
# learning rate < threshold
# [ 2/10 ] | train_loss = 0.62210, train_acc = 0.69792, val_loss = 0.53862, val_acc = 0.68750
# --------initializing regularization--------
# max loss:0.8301291465759277 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.58937, train_acc = 0.70573, val_loss = 0.40061, val_acc = 0.69792
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.57472, train_acc = 0.73438, val_loss = 0.73599, val_acc = 0.69792
# [ 2/10 ] | train_loss = 0.55371, train_acc = 0.73438, val_loss = 0.49292, val_acc = 0.71875
# --------initializing regularization--------
# max loss:0.7909181714057922 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.58965, train_acc = 0.71354, val_loss = 0.71880, val_acc = 0.68750
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.60951, train_acc = 0.68750, val_loss = 0.71944, val_acc = 0.66667
# [ 2/10 ] | train_loss = 0.60409, train_acc = 0.68490, val_loss = 0.45219, val_acc = 0.68750
# --------initializing regularization--------
# max loss:0.8676975965499878 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.61305, train_acc = 0.69271, val_loss = 0.70493, val_acc = 0.68750
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.58398, train_acc = 0.67969, val_loss = 0.55656, val_acc = 0.75000
# --------initializing regularization--------
# max loss:0.762573778629303 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.56822, train_acc = 0.74740, val_loss = 0.64279, val_acc = 0.71875
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.57274, train_acc = 0.72396, val_loss = 0.56674, val_acc = 0.75000
# learning rate < threshold
# [ 2/10 ] | train_loss = 0.58995, train_acc = 0.75521, val_loss = 0.59383, val_acc = 0.72917
# --------initializing regularization--------
# max loss:0.8251274228096008 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.56263, train_acc = 0.72656, val_loss = 0.52342, val_acc = 0.73958
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.56948, train_acc = 0.75000, val_loss = 0.58037, val_acc = 0.73958
# [ 2/10 ] | train_loss = 0.56764, train_acc = 0.72656, val_loss = 0.60881, val_acc = 0.75000
# --------initializing regularization--------
# max loss:0.7908616065979004 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.56715, train_acc = 0.73958, val_loss = 0.79086, val_acc = 0.71875
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.58327, train_acc = 0.72396, val_loss = 0.57711, val_acc = 0.70833
# learning rate < threshold
# [ 2/10 ] | train_loss = 0.59106, train_acc = 0.72135, val_loss = 0.52997, val_acc = 0.71875
# --------initializing regularization--------
# max loss:0.7698730826377869 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.57598, train_acc = 0.73177, val_loss = 0.52395, val_acc = 0.75000
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.58861, train_acc = 0.69010, val_loss = 0.77164, val_acc = 0.73958
# --------initializing regularization--------
# max loss:0.8961446285247803 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.60907, train_acc = 0.70833, val_loss = 0.74610, val_acc = 0.68750
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.56654, train_acc = 0.76042, val_loss = 0.69567, val_acc = 0.72917
# --------initializing regularization--------
# max loss:0.7143649458885193 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.55224, train_acc = 0.74740, val_loss = 0.59976, val_acc = 0.71875
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.59685, train_acc = 0.67708, val_loss = 0.54970, val_acc = 0.68750
# learning rate < threshold
# [ 2/10 ] | train_loss = 0.61215, train_acc = 0.67448, val_loss = 0.74923, val_acc = 0.65625
# --------initializing regularization--------
# max loss:0.7929198741912842 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.55401, train_acc = 0.73438, val_loss = 0.38519, val_acc = 0.72917
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.57101, train_acc = 0.71615, val_loss = 0.52297, val_acc = 0.71875
# --------initializing regularization--------
# max loss:0.815825879573822 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.57224, train_acc = 0.73177, val_loss = 0.47120, val_acc = 0.72917
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.61677, train_acc = 0.70833, val_loss = 0.45990, val_acc = 0.67708
# [ 2/10 ] | train_loss = 0.60430, train_acc = 0.67969, val_loss = 0.44645, val_acc = 0.66667
# [ 3/10 ] | train_loss = 0.60415, train_acc = 0.68229, val_loss = 0.76784, val_acc = 0.64583
# learning rate < threshold
# [ 4/10 ] | train_loss = 0.60604, train_acc = 0.66927, val_loss = 0.45672, val_acc = 0.68750
# --------initializing regularization--------
# max loss:0.8806373476982117 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.57884, train_acc = 0.70833, val_loss = 0.49791, val_acc = 0.71875
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.57177, train_acc = 0.72656, val_loss = 0.62403, val_acc = 0.67708
# --------initializing regularization--------
# max loss:0.7806249260902405 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.58398, train_acc = 0.71094, val_loss = 0.60556, val_acc = 0.66667
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.56137, train_acc = 0.73958, val_loss = 0.43499, val_acc = 0.71875
# --------initializing regularization--------
# max loss:0.764623761177063 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.57578, train_acc = 0.72656, val_loss = 0.69443, val_acc = 0.72917
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.58079, train_acc = 0.71094, val_loss = 0.51236, val_acc = 0.67708
# [ 2/10 ] | train_loss = 0.56863, train_acc = 0.73958, val_loss = 0.62463, val_acc = 0.68750
# learning rate < threshold
# [ 3/10 ] | train_loss = 0.58911, train_acc = 0.70833, val_loss = 0.37053, val_acc = 0.70833
# --------initializing regularization--------
# max loss:0.8131802082061768 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.57144, train_acc = 0.72917, val_loss = 0.59124, val_acc = 0.71875
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.56471, train_acc = 0.74479, val_loss = 0.48849, val_acc = 0.76042
# --------initializing regularization--------
# [ 1 ] | train_loss = 0.54914, train_acc = 0.73698, val_loss = 0.49591, val_acc = 0.72917
# learning <= threshold, stop training.
# [ 2 ] | train_loss = 0.55758, train_acc = 0.73958, val_loss = 0.54209, val_acc = 0.75000
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.57156, train_acc = 0.73438, val_loss = 0.57842, val_acc = 0.72917
# --------initializing regularization--------
# max loss:0.7865123748779297 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.57712, train_acc = 0.70833, val_loss = 0.63195, val_acc = 0.72917
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.57455, train_acc = 0.72656, val_loss = 0.37779, val_acc = 0.73958
# --------initializing regularization--------
# max loss:0.7616283297538757 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.54565, train_acc = 0.77865, val_loss = 0.41139, val_acc = 0.75000
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.57759, train_acc = 0.70833, val_loss = 0.50611, val_acc = 0.63542
# learning rate < threshold
# [ 2/10 ] | train_loss = 0.58516, train_acc = 0.71354, val_loss = 0.69714, val_acc = 0.70833
# --------initializing regularization--------
# max loss:0.7738751173019409 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.56765, train_acc = 0.75781, val_loss = 0.65751, val_acc = 0.76042
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.57272, train_acc = 0.73698, val_loss = 0.55327, val_acc = 0.71875
# --------initializing regularization--------
# max loss:0.8059989213943481 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.60120, train_acc = 0.69531, val_loss = 0.49552, val_acc = 0.73958
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.56063, train_acc = 0.76302, val_loss = 0.71735, val_acc = 0.71875
# [ 2/10 ] | train_loss = 0.56000, train_acc = 0.75521, val_loss = 0.71815, val_acc = 0.72917
# --------initializing regularization--------
# max loss:0.8227125406265259 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.55342, train_acc = 0.72917, val_loss = 0.49187, val_acc = 0.73958
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.61417, train_acc = 0.70833, val_loss = 0.56602, val_acc = 0.66667
# [ 2/10 ] | train_loss = 0.60470, train_acc = 0.69271, val_loss = 0.51704, val_acc = 0.69792
# --------initializing regularization--------
# max loss:0.824701726436615 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.61169, train_acc = 0.70312, val_loss = 0.49608, val_acc = 0.69792
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.58462, train_acc = 0.70573, val_loss = 0.71619, val_acc = 0.68750
# [ 2/10 ] | train_loss = 0.57522, train_acc = 0.72917, val_loss = 0.56044, val_acc = 0.68750
# --------initializing regularization--------
# max loss:0.8342273831367493 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.58231, train_acc = 0.70312, val_loss = 0.52341, val_acc = 0.68750
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.60097, train_acc = 0.71094, val_loss = 0.57803, val_acc = 0.66667
# [ 2/10 ] | train_loss = 0.59914, train_acc = 0.68750, val_loss = 0.46674, val_acc = 0.68750
# --------initializing regularization--------
# max loss:0.846453845500946 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.59788, train_acc = 0.71094, val_loss = 0.65119, val_acc = 0.68750
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.58738, train_acc = 0.72656, val_loss = 0.73387, val_acc = 0.65625
# --------initializing regularization--------
# max loss:0.7857009768486023 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.58461, train_acc = 0.69531, val_loss = 0.48885, val_acc = 0.69792
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.60044, train_acc = 0.71094, val_loss = 0.72895, val_acc = 0.68750
# [ 2/10 ] | train_loss = 0.58226, train_acc = 0.69531, val_loss = 0.49158, val_acc = 0.67708
# --------initializing regularization--------
# max loss:0.7993876338005066 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.60491, train_acc = 0.70573, val_loss = 0.54364, val_acc = 0.69792
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.61630, train_acc = 0.69010, val_loss = 0.50368, val_acc = 0.62500
# learning rate < threshold
# [ 2/10 ] | train_loss = 0.62571, train_acc = 0.68490, val_loss = 0.74261, val_acc = 0.62500
# --------initializing regularization--------
# max loss:0.725622832775116 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.58867, train_acc = 0.71094, val_loss = 0.56693, val_acc = 0.68750
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.56771, train_acc = 0.70573, val_loss = 0.54955, val_acc = 0.69792
# --------initializing regularization--------
# max loss:0.7759851813316345 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.57836, train_acc = 0.72917, val_loss = 0.56841, val_acc = 0.71875
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.56099, train_acc = 0.75781, val_loss = 0.46944, val_acc = 0.72917
# --------initializing regularization--------
# max loss:0.7890010476112366 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.55970, train_acc = 0.74740, val_loss = 0.52685, val_acc = 0.72917
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.59791, train_acc = 0.71615, val_loss = 0.43438, val_acc = 0.68750
# --------initializing regularization--------
# max loss:0.7683717012405396 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.59804, train_acc = 0.71615, val_loss = 0.52117, val_acc = 0.69792
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.57504, train_acc = 0.72135, val_loss = 0.54634, val_acc = 0.73958
# --------initializing regularization--------
# max loss:0.7475466132164001 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.58512, train_acc = 0.72396, val_loss = 0.65889, val_acc = 0.72917
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.57376, train_acc = 0.73958, val_loss = 0.58101, val_acc = 0.68750
# --------initializing regularization--------
# max loss:0.7807103991508484 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.56564, train_acc = 0.72656, val_loss = 0.50238, val_acc = 0.70833
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.59381, train_acc = 0.72396, val_loss = 0.75825, val_acc = 0.69792
# --------initializing regularization--------
# max loss:0.8135957717895508 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.60281, train_acc = 0.70833, val_loss = 0.60004, val_acc = 0.72917
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.58774, train_acc = 0.73177, val_loss = 0.57170, val_acc = 0.70833
# --------initializing regularization--------
# max loss:0.7739013433456421 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.60177, train_acc = 0.68490, val_loss = 0.68197, val_acc = 0.71875
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.59060, train_acc = 0.73177, val_loss = 0.48444, val_acc = 0.69792
# --------initializing regularization--------
# max loss:0.806786298751831 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.59227, train_acc = 0.71875, val_loss = 0.80679, val_acc = 0.69792
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.58574, train_acc = 0.69792, val_loss = 0.63954, val_acc = 0.69792
# --------initializing regularization--------
# max loss:0.7187920808792114 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.57416, train_acc = 0.71875, val_loss = 0.40028, val_acc = 0.72917
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.62939, train_acc = 0.65104, val_loss = 0.88300, val_acc = 0.64583
# [ 2/10 ] | train_loss = 0.62179, train_acc = 0.66667, val_loss = 0.52472, val_acc = 0.67708
# [ 3/10 ] | train_loss = 0.60623, train_acc = 0.69271, val_loss = 0.60034, val_acc = 0.65625
# learning rate < threshold
# [ 4/10 ] | train_loss = 0.61873, train_acc = 0.68490, val_loss = 0.61213, val_acc = 0.68750
# --------initializing regularization--------
# max loss:0.7119669318199158 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.57269, train_acc = 0.73177, val_loss = 0.60940, val_acc = 0.69792
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.62111, train_acc = 0.67708, val_loss = 0.57736, val_acc = 0.69792
# --------initializing regularization--------
# max loss:0.8119039535522461 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.60973, train_acc = 0.67708, val_loss = 0.64718, val_acc = 0.67708
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.58917, train_acc = 0.70833, val_loss = 0.58846, val_acc = 0.68750
# --------initializing regularization--------
# max loss:0.7936691045761108 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.58855, train_acc = 0.71615, val_loss = 0.71244, val_acc = 0.67708
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.60956, train_acc = 0.69792, val_loss = 0.55207, val_acc = 0.64583
# [ 2/10 ] | train_loss = 0.60033, train_acc = 0.70312, val_loss = 0.42849, val_acc = 0.66667
# --------initializing regularization--------
# max loss:0.8178980350494385 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.61857, train_acc = 0.69010, val_loss = 0.64504, val_acc = 0.67708
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.56123, train_acc = 0.74479, val_loss = 0.55528, val_acc = 0.68750
# --------initializing regularization--------
# max loss:0.7569724321365356 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.57997, train_acc = 0.72656, val_loss = 0.51156, val_acc = 0.71875
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.61841, train_acc = 0.68229, val_loss = 0.55454, val_acc = 0.67708
# [ 2/10 ] | train_loss = 0.60477, train_acc = 0.70052, val_loss = 0.62757, val_acc = 0.63542
# --------initializing regularization--------
# max loss:0.8019746541976929 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.61746, train_acc = 0.68229, val_loss = 0.56663, val_acc = 0.65625
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.62338, train_acc = 0.67188, val_loss = 0.67485, val_acc = 0.66667
# [ 2/10 ] | train_loss = 0.62291, train_acc = 0.66406, val_loss = 0.61435, val_acc = 0.62500
# [ 3/10 ] | train_loss = 0.61106, train_acc = 0.65885, val_loss = 0.67943, val_acc = 0.64583
# --------initializing regularization--------
# max loss:0.8365975618362427 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.62098, train_acc = 0.67969, val_loss = 0.71469, val_acc = 0.63542
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.57488, train_acc = 0.72135, val_loss = 0.59341, val_acc = 0.68750
# --------initializing regularization--------
# max loss:0.7729045748710632 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.58120, train_acc = 0.72396, val_loss = 0.72002, val_acc = 0.68750
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.56092, train_acc = 0.74219, val_loss = 0.45010, val_acc = 0.69792
# [ 2/10 ] | train_loss = 0.55749, train_acc = 0.75000, val_loss = 0.36382, val_acc = 0.71875
# --------initializing regularization--------
# max loss:0.7113468647003174 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.56905, train_acc = 0.71875, val_loss = 0.57665, val_acc = 0.68750
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.57247, train_acc = 0.74219, val_loss = 0.63507, val_acc = 0.68750
# --------initializing regularization--------
# max loss:0.7530980706214905 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.58279, train_acc = 0.72917, val_loss = 0.55732, val_acc = 0.67708
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.59589, train_acc = 0.71354, val_loss = 0.52829, val_acc = 0.66667
# --------initializing regularization--------
# max loss:0.783797562122345 > threshold0.7, stop training.
# [ 1 ] | train_loss = 0.62149, train_acc = 0.70052, val_loss = 0.71481, val_acc = 0.66667
# --------initializing weight tuning--------
# [ 1/10 ] | train_loss = 0.61043, train_acc = 0.69531, val_loss = 0.57936, val_acc = 0.64583
# [ 2/10 ] | train_loss = 0.61014, train_acc = 0.69271, val_loss = 0.57836, val_acc = 0.66667

# %%
print(model)
# Out:
# TwoLayerNN(
#   (layer_1): Linear(in_features=12, out_features=91, bias=True)
#   (layer_out): Linear(in_features=91, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (bn): BatchNorm1d(91, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
epochs = 20
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-3)

model = train(train_loader, val_loader, model=model, epochs=epochs, optimizer=optimizer, criterion=criterion, device=device)
# Out:
# [ 1/20 ] | train_loss = 0.60084, train_acc = 0.71615, val_loss = 0.62785, val_acc = 0.64583
# [ 2/20 ] | train_loss = 0.59332, train_acc = 0.68229, val_loss = 0.60762, val_acc = 0.64583
# [ 3/20 ] | train_loss = 0.59883, train_acc = 0.69792, val_loss = 0.43327, val_acc = 0.65625
# [ 4/20 ] | train_loss = 0.59171, train_acc = 0.71875, val_loss = 0.65076, val_acc = 0.67708
# [ 5/20 ] | train_loss = 0.58432, train_acc = 0.70312, val_loss = 0.59891, val_acc = 0.69792
# [ 6/20 ] | train_loss = 0.56788, train_acc = 0.71875, val_loss = 0.52334, val_acc = 0.69792
# [ 7/20 ] | train_loss = 0.56887, train_acc = 0.74479, val_loss = 0.56552, val_acc = 0.69792
# [ 8/20 ] | train_loss = 0.57621, train_acc = 0.70833, val_loss = 0.54646, val_acc = 0.70833
# [ 9/20 ] | train_loss = 0.55905, train_acc = 0.75260, val_loss = 0.71248, val_acc = 0.68750
# [ 10/20 ] | train_loss = 0.56056, train_acc = 0.75000, val_loss = 0.64607, val_acc = 0.69792
# [ 11/20 ] | train_loss = 0.56949, train_acc = 0.72396, val_loss = 0.55362, val_acc = 0.69792
# [ 12/20 ] | train_loss = 0.55316, train_acc = 0.74219, val_loss = 0.63767, val_acc = 0.70833
# [ 13/20 ] | train_loss = 0.55336, train_acc = 0.73177, val_loss = 0.54822, val_acc = 0.68750
# [ 14/20 ] | train_loss = 0.55610, train_acc = 0.73177, val_loss = 0.55546, val_acc = 0.71875
# [ 15/20 ] | train_loss = 0.54637, train_acc = 0.74479, val_loss = 0.58018, val_acc = 0.69792
# [ 16/20 ] | train_loss = 0.53189, train_acc = 0.76302, val_loss = 0.44148, val_acc = 0.70833
# [ 17/20 ] | train_loss = 0.52896, train_acc = 0.73177, val_loss = 0.65904, val_acc = 0.71875
# [ 18/20 ] | train_loss = 0.52710, train_acc = 0.76042, val_loss = 0.61189, val_acc = 0.70833
# [ 19/20 ] | train_loss = 0.52871, train_acc = 0.75000, val_loss = 0.43722, val_acc = 0.71875
# [ 20/20 ] | train_loss = 0.52273, train_acc = 0.75260, val_loss = 0.37520, val_acc = 0.71875
