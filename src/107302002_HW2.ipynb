# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import itertools

from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.preprocessing import StandardScaler

# %%
class CustomDataset(Dataset):
    
    def __init__(self, filepath) -> None:
        
        # load csv data
        data = pd.read_csv(filepath, header=None)
        X = data.iloc[:, :-1].values
        y = data.iloc[:, -1].values
        
        # feature scaling
        sc = StandardScaler()
        X = sc.fit_transform(X)
        
        # convert to tensors
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y)
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, index):
        return self.X[index], self.y[index]

# %%
dataset = CustomDataset('../data/train_all_0.csv')

# create data indices for train val split
data_size = len(dataset)
indices = list(range(data_size))
split = int(np.floor(0.2 * data_size))
np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]

train_sampler = SubsetRandomSampler(train_indices)
val_sampler = SubsetRandomSampler(val_indices)

# create data loader
train_loader = DataLoader(dataset, batch_size=16, sampler=train_sampler)
val_loader = DataLoader(dataset, batch_size=16, sampler=val_sampler)

# %%
class BinaryClassification(nn.Module):
    def __init__(self):
        super(BinaryClassification, self).__init__()
        self.layer_1 = nn.Linear(12, 128) 
        self.layer_out = nn.Linear(128, 2) 
        self.relu = nn.ReLU()
        
    def forward(self, inputs):
        x = self.relu(self.layer_1(inputs))
        x = self.layer_out(x)
        
        return x

# %%
# create training pipeline based on page 49
def P49_train(train_loader=train_loader, val_loader=val_loader, model=None, epochs=None, criterion=None, optimizer=None, loss_threshold=0.5):
    '''When iterating over 50 or validation loss smaller than specific number, the function will stop'''
    for epoch in range(epochs):
        
        model.train()
        train_loss = []
        train_accs = []
        
        for batch in train_loader:
            
            x, y = batch
            
            logits = model(x.to(device))
            loss = criterion(logits, y.to(device))
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            acc = (logits.argmax(dim=-1) == y.to(device)).float().mean()
            train_loss.append(loss.item())
            train_accs.append(acc)
        
        train_loss = sum(train_loss) / len(train_loss)
        train_acc = sum(train_accs) / len(train_accs)
        
        model.eval()

        valid_loss = []
        valid_accs = []
        
        for batch in val_loader:
            imgs, labels = batch
            
            with torch.no_grad():
                logits = model(imgs.to(device))
                
                acc = (logits.argmax(dim=-1) == labels.to(device)).float().mean()
                
                valid_loss.append(loss.item())
                valid_accs.append(acc)
        
        valid_loss = sum(valid_loss) / len(valid_loss)
        valid_acc = sum(valid_accs) / len(valid_accs)
        
        print(f'[ {epoch+1}/{epochs} ] | train_loss = {train_loss:.5f}, train_acc = {train_acc:.5f}, val_loss = {valid_loss:.5f}, val_acc = {valid_acc:.5f}')
        
        if epoch+1 >= 50:
            print("It's over 50 epochs, stop training")    
            break
        
        if train_loss < loss_threshold:
            print('The training loss is smaller than what you want, stop training')
            break

# %%
# create training pipeline based on page 50
def P50_train(train_loader=train_loader, val_loader=val_loader, model=None, epochs=None, criterion=None, optimizer=None, loss_threshold=0.5, eta_threshold=0.008):
    '''
    When iterating over 50 or validation loss smaller than specific number, the function will stop.
    Also, if the new loss is larger than the previous one, it will compare the learning rate and the threshold.
    if the learning rate is larger than the threshold, use the old weight and the learning rate will multiply 0.7 and do bp one more time.
    if not, then stop training.
    However if the new loss is smaller than the previous one, update w to new weight and multiply learning rate by 1.2, and going through new loop
    '''
    
    previous_train_loss = 10000    

    for epoch in range(epochs):
        
        model.train()
        
        previous_model_params = model.state_dict()
        stop_training = False
        
        while optimizer.param_groups[0]['lr'] > eta_threshold:
            
            train_loss = []
            train_accs = []
            
            for batch in train_loader:
                
                x, y = batch
                
                logits = model(x.to(device))
                loss = criterion(logits, y.to(device))
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
                acc = (logits.argmax(dim=-1) == y.to(device)).float().mean()
                train_loss.append(loss.item())
                train_accs.append(acc)
            
            train_loss = sum(train_loss) / len(train_loss)
            train_acc = sum(train_accs) / len(train_accs)
            
            if train_loss < previous_train_loss:
                optimizer.param_groups[0]['lr'] *= 1.2
                previous_train_loss = train_loss
                print(f'The previous training loss is: {previous_train_loss}')
                break
            
            optimizer.param_groups[0]['lr'] *= 0.7
            model.load_state_dict(previous_model_params)
            current_lr = optimizer.param_groups[0]['lr']
            print(f'lr shrinking!, now the lr is: {current_lr}')
            
        else:
            stop_training = True
        
        # Use try and except to detect whether the eta_threshold is set too high initially
        try:        
            model.eval()
            valid_loss = []
            valid_accs = []
            
            for batch in val_loader:
                imgs, labels = batch
                
                with torch.no_grad():
                    logits = model(imgs.to(device))
                    
                    acc = (logits.argmax(dim=-1) == labels.to(device)).float().mean()
                    valid_loss.append(loss.item())
                    valid_accs.append(acc)
            
            valid_loss = sum(valid_loss) / len(valid_loss)
            valid_acc = sum(valid_accs) / len(valid_accs)
        
            print(f'[ {epoch+1}/{epochs} ] | train_loss = {train_loss:.5f}, train_acc = {train_acc:.5f}, val_loss = {valid_loss:.5f}, val_acc = {valid_acc:.5f}')
            
        except UnboundLocalError:
            print('Your eta_threshold is setting higher than your learning rate. Reset it with lower one!')
        
        # stopping criterion
        if stop_training:
            print('Learning rate is smaller than the threshold, stop training.')
            break
        
        if epoch+1 >= 50:
            print('It over 50 epochs, stop training.')
            break
        
        if train_loss < loss_threshold:
            print('The training loss is smaller than what you want, stop training.')
            break

# %%
# create training pipeline based on page 58
def P58_train(train_loader=train_loader, val_loader=val_loader, model=None, criterion=None, optimizer=None, loss_threshold=0.5, eta_threshold=0.008):
    '''
    Almost the same as P50, but without training epochs.
    '''
    
    previous_train_loss = 10000    

    for epoch in itertools.count():
        
        model.train()
        
        previous_model_params = model.state_dict()
        stop_training = False
        
        while optimizer.param_groups[0]['lr'] > eta_threshold:
            
            train_loss = []
            train_accs = []
            
            for batch in train_loader:
                
                x, y = batch
                
                logits = model(x.to(device))
                loss = criterion(logits, y.to(device))
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
                acc = (logits.argmax(dim=-1) == y.to(device)).float().mean()
                train_loss.append(loss.item())
                train_accs.append(acc)
            
            train_loss = sum(train_loss) / len(train_loss)
            train_acc = sum(train_accs) / len(train_accs)
            
            if train_loss < previous_train_loss:
                optimizer.param_groups[0]['lr'] *= 1.2
                previous_train_loss = train_loss
                print(f'The previous training loss is: {previous_train_loss}')
                break
            
            optimizer.param_groups[0]['lr'] *= 0.7
            model.load_state_dict(previous_model_params)
            current_lr = optimizer.param_groups[0]['lr']
            print(f'lr shrinking!, now the lr is: {current_lr}')
            
        else:
            stop_training = True
        
        # Use try and except to detect whether the eta_threshold is set too high initially
        try:        
            model.eval()
            valid_loss = []
            valid_accs = []
            
            for batch in val_loader:
                imgs, labels = batch
                
                with torch.no_grad():
                    logits = model(imgs.to(device))
                    
                    acc = (logits.argmax(dim=-1) == labels.to(device)).float().mean()
                    valid_loss.append(loss.item())
                    valid_accs.append(acc)
            
            valid_loss = sum(valid_loss) / len(valid_loss)
            valid_acc = sum(valid_accs) / len(valid_accs)
        
            print(f'[ {epoch+1}/{epochs} ] | train_loss = {train_loss:.5f}, train_acc = {train_acc:.5f}, val_loss = {valid_loss:.5f}, val_acc = {valid_acc:.5f}')
            
        except UnboundLocalError:
            print('Your eta_threshold is setting higher than your learning rate. Reset it with lower one!')
        
        # stopping criterion
        if stop_training:
            print('Learning rate is smaller than the threshold, stop training.')
            break
        
        if train_loss < loss_threshold:
            print('The training loss is smaller than what you want, stop training.')
            break

# %%
epochs = 100
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = BinaryClassification().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 1e-3)
P49_train(train_loader, val_loader, model, epochs, criterion, optimizer, loss_threshold=0.2)
# Out:
# [ 1/100 ] | train_loss = 0.57666, train_acc = 0.70573, val_loss = 0.37518, val_acc = 0.83333
# [ 2/100 ] | train_loss = 0.42514, train_acc = 0.82552, val_loss = 0.54065, val_acc = 0.86458
# [ 3/100 ] | train_loss = 0.37309, train_acc = 0.86458, val_loss = 0.30738, val_acc = 0.84375
# [ 4/100 ] | train_loss = 0.34173, train_acc = 0.87760, val_loss = 0.24397, val_acc = 0.87500
# [ 5/100 ] | train_loss = 0.32258, train_acc = 0.87240, val_loss = 0.25656, val_acc = 0.88542
# [ 6/100 ] | train_loss = 0.30682, train_acc = 0.88802, val_loss = 0.77175, val_acc = 0.89583
# [ 7/100 ] | train_loss = 0.29765, train_acc = 0.89844, val_loss = 0.26842, val_acc = 0.88542
# [ 8/100 ] | train_loss = 0.28747, train_acc = 0.89583, val_loss = 0.22019, val_acc = 0.88542
# [ 9/100 ] | train_loss = 0.27871, train_acc = 0.89844, val_loss = 0.21673, val_acc = 0.88542
# [ 10/100 ] | train_loss = 0.27159, train_acc = 0.90625, val_loss = 0.11994, val_acc = 0.88542
# [ 11/100 ] | train_loss = 0.26526, train_acc = 0.91406, val_loss = 0.11473, val_acc = 0.87500
# [ 12/100 ] | train_loss = 0.25872, train_acc = 0.91667, val_loss = 0.27297, val_acc = 0.88542
# [ 13/100 ] | train_loss = 0.25422, train_acc = 0.91406, val_loss = 0.19936, val_acc = 0.86458
# [ 14/100 ] | train_loss = 0.24842, train_acc = 0.91667, val_loss = 0.09877, val_acc = 0.86458
# [ 15/100 ] | train_loss = 0.24238, train_acc = 0.91667, val_loss = 0.09412, val_acc = 0.87500
# [ 16/100 ] | train_loss = 0.23570, train_acc = 0.91927, val_loss = 0.37895, val_acc = 0.87500
# [ 17/100 ] | train_loss = 0.23312, train_acc = 0.91927, val_loss = 0.46626, val_acc = 0.87500
# [ 18/100 ] | train_loss = 0.22633, train_acc = 0.92188, val_loss = 0.37069, val_acc = 0.88542
# [ 19/100 ] | train_loss = 0.22170, train_acc = 0.91927, val_loss = 0.28289, val_acc = 0.87500
# [ 20/100 ] | train_loss = 0.21495, train_acc = 0.92708, val_loss = 0.11399, val_acc = 0.86458
# [ 21/100 ] | train_loss = 0.21216, train_acc = 0.93490, val_loss = 0.11427, val_acc = 0.87500
# [ 22/100 ] | train_loss = 0.20659, train_acc = 0.93229, val_loss = 0.17422, val_acc = 0.86458
# [ 23/100 ] | train_loss = 0.20195, train_acc = 0.92969, val_loss = 0.17025, val_acc = 0.87500
# [ 24/100 ] | train_loss = 0.19700, train_acc = 0.93229, val_loss = 0.13818, val_acc = 0.87500
# The training loss is smaller than what you want, stop training

# %%
epochs = 100
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = BinaryClassification().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 1e-3)
P50_train(train_loader, val_loader, model, epochs, criterion, optimizer, loss_threshold=0.05, eta_threshold=9e-4)
# Out:
# The previous training loss is: 0.5601096078753471
# [ 1/100 ] | train_loss = 0.56011, train_acc = 0.78646, val_loss = 0.50863, val_acc = 0.83333
# The previous training loss is: 0.44109678640961647
# [ 2/100 ] | train_loss = 0.44110, train_acc = 0.81510, val_loss = 0.52197, val_acc = 0.85417
# The previous training loss is: 0.37545802630484104
# [ 3/100 ] | train_loss = 0.37546, train_acc = 0.84896, val_loss = 0.25889, val_acc = 0.84375
# The previous training loss is: 0.33619561046361923
# [ 4/100 ] | train_loss = 0.33620, train_acc = 0.86198, val_loss = 0.29675, val_acc = 0.87500
# The previous training loss is: 0.3092994410544634
# [ 5/100 ] | train_loss = 0.30930, train_acc = 0.87500, val_loss = 0.13201, val_acc = 0.84375
# The previous training loss is: 0.2889921034996708
# [ 6/100 ] | train_loss = 0.28899, train_acc = 0.89844, val_loss = 0.37172, val_acc = 0.87500
# The previous training loss is: 0.27357610656569403
# [ 7/100 ] | train_loss = 0.27358, train_acc = 0.89323, val_loss = 0.12459, val_acc = 0.89583
# The previous training loss is: 0.25512771556774777
# [ 8/100 ] | train_loss = 0.25513, train_acc = 0.90625, val_loss = 0.11788, val_acc = 0.88542
# The previous training loss is: 0.2442590935776631
# [ 9/100 ] | train_loss = 0.24426, train_acc = 0.91146, val_loss = 0.46110, val_acc = 0.85417
# The previous training loss is: 0.2264797417446971
# [ 10/100 ] | train_loss = 0.22648, train_acc = 0.90885, val_loss = 0.12037, val_acc = 0.89583
# The previous training loss is: 0.20050674056013426
# [ 11/100 ] | train_loss = 0.20051, train_acc = 0.92448, val_loss = 0.20477, val_acc = 0.86458
# lr shrinking!, now the lr is: 0.005201058594815997
# The previous training loss is: 0.17715985079606375
# [ 12/100 ] | train_loss = 0.17716, train_acc = 0.93490, val_loss = 0.05289, val_acc = 0.87500
# The previous training loss is: 0.16993899969384074
# [ 13/100 ] | train_loss = 0.16994, train_acc = 0.93750, val_loss = 0.12162, val_acc = 0.89583
# The previous training loss is: 0.1688077187476059
# [ 14/100 ] | train_loss = 0.16881, train_acc = 0.94271, val_loss = 0.04630, val_acc = 0.91667
# The previous training loss is: 0.15177845931611955
# [ 15/100 ] | train_loss = 0.15178, train_acc = 0.95052, val_loss = 0.02152, val_acc = 0.91667
# lr shrinking!, now the lr is: 0.007549440571547314
# lr shrinking!, now the lr is: 0.005284608400083119
# The previous training loss is: 0.13074077105072016
# [ 16/100 ] | train_loss = 0.13074, train_acc = 0.95312, val_loss = 0.23525, val_acc = 0.89583
# The previous training loss is: 0.11140561425903191
# [ 17/100 ] | train_loss = 0.11141, train_acc = 0.95573, val_loss = 0.03676, val_acc = 0.84375
# The previous training loss is: 0.10848570987582207
# [ 18/100 ] | train_loss = 0.10849, train_acc = 0.96094, val_loss = 0.03743, val_acc = 0.91667
# The previous training loss is: 0.1025183192299058
# [ 19/100 ] | train_loss = 0.10252, train_acc = 0.97135, val_loss = 0.04350, val_acc = 0.89583
# lr shrinking!, now the lr is: 0.0076707147848886475
# lr shrinking!, now the lr is: 0.005369500349422053
# The previous training loss is: 0.10213336627930403
# [ 20/100 ] | train_loss = 0.10213, train_acc = 0.95833, val_loss = 0.07052, val_acc = 0.90625
# The previous training loss is: 0.08306572656147182
# [ 21/100 ] | train_loss = 0.08307, train_acc = 0.97917, val_loss = 0.04568, val_acc = 0.90625
# The previous training loss is: 0.07183061943699916
# [ 22/100 ] | train_loss = 0.07183, train_acc = 0.97656, val_loss = 0.02800, val_acc = 0.90625
# lr shrinking!, now the lr is: 0.006494947622660914
# The previous training loss is: 0.06927683534255873
# [ 23/100 ] | train_loss = 0.06928, train_acc = 0.97656, val_loss = 0.06326, val_acc = 0.90625
# lr shrinking!, now the lr is: 0.005455756003035168
# The previous training loss is: 0.05657307629007846
# [ 24/100 ] | train_loss = 0.05657, train_acc = 0.98438, val_loss = 0.18369, val_acc = 0.91667
# The previous training loss is: 0.05000813394629707
# [ 25/100 ] | train_loss = 0.05001, train_acc = 0.98958, val_loss = 0.10806, val_acc = 0.91667
# lr shrinking!, now the lr is: 0.005499402051059447
# lr shrinking!, now the lr is: 0.003849581435741613
# The previous training loss is: 0.037836058860799916
# [ 26/100 ] | train_loss = 0.03784, train_acc = 0.99740, val_loss = 0.03149, val_acc = 0.91667
# The training loss is smaller than what you want, stop training.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = BinaryClassification().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 1e-3)
P58_train(train_loader, val_loader, model, criterion, optimizer, loss_threshold=0.05, eta_threshold=9e-4)
# Out:
# The previous training loss is: 0.6519167224566141
# [ 1/100 ] | train_loss = 0.65192, train_acc = 0.63281, val_loss = 0.59518, val_acc = 0.83333
# The previous training loss is: 0.47752015478909016
# [ 2/100 ] | train_loss = 0.47752, train_acc = 0.81250, val_loss = 0.59318, val_acc = 0.83333
# The previous training loss is: 0.3995066260298093
# [ 3/100 ] | train_loss = 0.39951, train_acc = 0.84635, val_loss = 0.31210, val_acc = 0.83333
# The previous training loss is: 0.35225291550159454
# [ 4/100 ] | train_loss = 0.35225, train_acc = 0.86198, val_loss = 0.29602, val_acc = 0.84375
# The previous training loss is: 0.3276235417773326
# [ 5/100 ] | train_loss = 0.32762, train_acc = 0.85417, val_loss = 0.30539, val_acc = 0.85417
# The previous training loss is: 0.30202035419642925
# [ 6/100 ] | train_loss = 0.30202, train_acc = 0.88281, val_loss = 0.32821, val_acc = 0.87500
# The previous training loss is: 0.28464382079740363
# [ 7/100 ] | train_loss = 0.28464, train_acc = 0.89583, val_loss = 0.54565, val_acc = 0.86458
# The previous training loss is: 0.2672839347893993
# [ 8/100 ] | train_loss = 0.26728, train_acc = 0.90365, val_loss = 0.39173, val_acc = 0.87500
# The previous training loss is: 0.2480563580368956
# [ 9/100 ] | train_loss = 0.24806, train_acc = 0.89844, val_loss = 0.41550, val_acc = 0.87500
# The previous training loss is: 0.23278323778261742
# [ 10/100 ] | train_loss = 0.23278, train_acc = 0.91146, val_loss = 0.15359, val_acc = 0.82292
# lr shrinking!, now the lr is: 0.004334215495679998
# The previous training loss is: 0.19244432852913937
# [ 11/100 ] | train_loss = 0.19244, train_acc = 0.93750, val_loss = 0.05923, val_acc = 0.86458
# The previous training loss is: 0.1911469867142538
# [ 12/100 ] | train_loss = 0.19115, train_acc = 0.93750, val_loss = 0.23141, val_acc = 0.87500
# The previous training loss is: 0.1733957358325521
# [ 13/100 ] | train_loss = 0.17340, train_acc = 0.94010, val_loss = 0.22685, val_acc = 0.90625
# lr shrinking!, now the lr is: 0.0052426670635745245
# The previous training loss is: 0.14936126365015903
# [ 14/100 ] | train_loss = 0.14936, train_acc = 0.94792, val_loss = 0.04086, val_acc = 0.90625
# The previous training loss is: 0.1392030279772977
# [ 15/100 ] | train_loss = 0.13920, train_acc = 0.94792, val_loss = 0.03121, val_acc = 0.90625
# lr shrinking!, now the lr is: 0.00528460840008312
# The previous training loss is: 0.12840208768223724
# [ 16/100 ] | train_loss = 0.12840, train_acc = 0.95573, val_loss = 0.09874, val_acc = 0.90625
# The previous training loss is: 0.11326976531806092
# [ 17/100 ] | train_loss = 0.11327, train_acc = 0.95833, val_loss = 0.19589, val_acc = 0.91667
# lr shrinking!, now the lr is: 0.0053268852672837845
# The previous training loss is: 0.11150370274359982
# [ 18/100 ] | train_loss = 0.11150, train_acc = 0.95833, val_loss = 0.02126, val_acc = 0.91667
# The previous training loss is: 0.10401471929314236
# [ 19/100 ] | train_loss = 0.10401, train_acc = 0.96615, val_loss = 0.23450, val_acc = 0.92708
# lr shrinking!, now the lr is: 0.005369500349422054
# lr shrinking!, now the lr is: 0.0037586502445954373
# The previous training loss is: 0.0783467759223034
# [ 20/100 ] | train_loss = 0.07835, train_acc = 0.97135, val_loss = 0.07063, val_acc = 0.91667
# The previous training loss is: 0.06849389096411566
# [ 21/100 ] | train_loss = 0.06849, train_acc = 0.97917, val_loss = 0.01014, val_acc = 0.91667
# lr shrinking!, now the lr is: 0.0037887194465522
# The previous training loss is: 0.06729097516896825
# [ 22/100 ] | train_loss = 0.06729, train_acc = 0.98698, val_loss = 0.11506, val_acc = 0.90625
# The previous training loss is: 0.06457226750596116
# [ 23/100 ] | train_loss = 0.06457, train_acc = 0.98698, val_loss = 0.01468, val_acc = 0.91667
# lr shrinking!, now the lr is: 0.0038190292021246172
# The previous training loss is: 0.058968822743433215
# [ 24/100 ] | train_loss = 0.05897, train_acc = 0.98698, val_loss = 0.05434, val_acc = 0.90625
# The previous training loss is: 0.05651684409046235
# [ 25/100 ] | train_loss = 0.05652, train_acc = 0.98438, val_loss = 0.05361, val_acc = 0.91667
# lr shrinking!, now the lr is: 0.0038495814357416137
# The previous training loss is: 0.052424522931687534
# [ 26/100 ] | train_loss = 0.05242, train_acc = 0.99740, val_loss = 0.01419, val_acc = 0.91667
# The previous training loss is: 0.05132393701933324
# [ 27/100 ] | train_loss = 0.05132, train_acc = 0.98698, val_loss = 0.02914, val_acc = 0.90625
# The previous training loss is: 0.04725617820319409
# [ 28/100 ] | train_loss = 0.04726, train_acc = 0.99219, val_loss = 0.09242, val_acc = 0.91667
# The training loss is smaller than what you want, stop training.
